# %% [markdown]
# # Proyecto 1
# ## Mostrar informacion al usuario

# %%
print("semana de phyton en la práctica")
# Out:
# semana de phyton en la práctica

# %% [markdown]
# ## Recibir información del usuario

# %%
input("Escriba su clave:")
input("Cual es el mejor lenguaje de progrmaación: ")
# Out:
# Escriba su clave:0000
# Cual es el mejor lenguaje de progrmaación: phyton
# 'phyton'

# %% [markdown]
# ## Almacenando variables

# %%
proyecto = "Mi primer proyecto con python"

# %%
print(proyecto)
# Out:
# Mi primer proyecto con python

# %% [markdown]
# ## Mezclando los conceptos aprendidos

# %%
proyecto = input("Escriba la descripción del proyecto: ")
horas_estimadas= input("Escriba las horas estimadas para el proyecto: ")
valor_hora = input("¿Cual es el valor de la hora trabajada? ")
plazo_estimado= input("Escriba cuanto tiempo estima que va tomar el proyecto: ")
# Out:
# Escriba la descripción del proyecto: Análisis financiero
# Escriba las horas estimadas para el proyecto: 20
# ¿Cual es el valor de la hora trabajada? 20
# Escriba cuanto tiempo estima que va tomar el proyecto: 2 meses

# %%
print(proyecto)
# Out:
# Análisi financiero

# %%
print(proyecto)
print(horas_estimadas)
print(valor_hora)
print(plazo_estimado)
# Out:
# Análisis financiero
# 20
# 20
# 2 meses

# %% [markdown]
# ## Cálculos con Phyton

# %%
print(10+2)
# Out:
# 12

# %%
print(124-24)
# Out:
# 100

# %%
print(13*2)
# Out:
# 26

# %%
print(100/2)
# Out:
# 50.0

# %% [markdown]
# ## Calculando el valor total del proyecto

# %%
valor_total= int(horas_estimadas)*int(valor_hora)

# %%
print(valor_total)
# Out:
# 400

# %% [markdown]
# ## Generando archivos en PDF del protecto

# %%
# !pip install fpdf
# Out:
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40761 sha256=f3e2056c172cd55598c2f6b5876379d5c4f462c236bfed2f5f701f45b4ce8023
#   Stored in directory: /root/.cache/pip/wheels/aa/da/11/a3189f34ddc13c26a2d0f329eac46b728c7f31c39e4dc26243
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2

# %%
from fpdf import FPDF

# %%
pdf = FPDF()

pdf.add_page()
pdf.set_font("Arial")

pdf.text(115, 145, "proyecto")
pdf.text(115, 160, "horas_estimadas")
pdf.text(115, 175, "valor_hora")
pdf.text(115, 190, str("plazo_estimado"))

pdf.output("Presupuesto.pdf")
# Out:
# ''
